# %%
import numpy as np
import sys
print(sys.version)
# Out:
# 3.6.1 (default, Apr  4 2017, 09:40:21)
# [GCC 4.2.1 Compatible Apple LLVM 8.1.0 (clang-802.0.38)]

# %%
r_set = np.load('r_set.npy')
b_set = np.load('b_set.npy')

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.scatter(r_set[:,0], r_set[:,1], c='r')
plt.scatter(b_set[:,0], b_set[:,1], c='b')

# %%
plt.plot([-4, 4], [4, -4], 'k-', lw=2) # draw line y = -x
plt.scatter(r_set[:,0], r_set[:,1], c='r')
plt.scatter(b_set[:,0], b_set[:,1], c='b')
